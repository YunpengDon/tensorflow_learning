# %% [markdown]
# # 1. Import Keras

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print(tf.version)
print(tf.keras.__version__)
# Out:
# <module 'tensorflow_core._api.v2.version' from 'D:\\Users\\shelb\\Anaconda3\\lib\\site-packages\\tensorflow_core\\_api\\v2\\version\\__init__.py'>
# 2.2.4-tf

# %% [markdown]
# # 2. Build a model
# ## 2.1 Stack a model

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# ## 2.2 Network settings
#
# - `activation` : default='None'.
# - `kernel-initializer` and `bias-initializer` : define the way how weights get initialized. default=`Glorot uniform`.
# - `kernel-regularizer` and `bias-regularizer` : define the regulation method(L1, L2, etc.). default='None'.

# %%
# eg.
keras.layers.Dense(32, activation='sigmoid')
keras.layers.Dense(32, activation=tf.sigmoid)
keras.layers.Dense(32, kernel_initializer='orthogonal')
keras.layers.Dense(32, kernel_initializer=keras.initializers.glorot_normal)
keras.layers.Dense(32,kernel_regularizer=tf.keras.regularizers.l2(0.01))

# %% [markdown]
# # 3. Train and evaluate
# ## 3.1 Setting the learning process

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(optimizer=keras.optimizers.Adam(0.01), loss=keras.losses.categorical_crossentropy, metrics=[keras.metrics.categorical_accuracy])

# %% [markdown]
# ## 3.2 Input data

# %%
import numpy as np
train_x = np.random.random((1000, 72))
train_y = np.random.random((1000, 10))

val_x = np.random.random((200, 72))
val_y = np.random.random((200, 10))

model.fit(train_x, train_y, epochs=10, batch_size=100, validation_data=(val_x, val_y))
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/10
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 19.6887 - categorical_accuracy: 0.1330 - val_loss: 34.7482 - val_categorical_accuracy: 0.0950
# Epoch 2/10
# 1000/1000 [==============================] - 0s 53us/sample - loss: 49.9792 - categorical_accuracy: 0.1030 - val_loss: 72.2408 - val_categorical_accuracy: 0.0850
# Epoch 3/10
# 1000/1000 [==============================] - 0s 57us/sample - loss: 83.8156 - categorical_accuracy: 0.1010 - val_loss: 101.2759 - val_categorical_accuracy: 0.1150
# Epoch 4/10
# 1000/1000 [==============================] - 0s 45us/sample - loss: 105.7735 - categorical_accuracy: 0.0880 - val_loss: 121.6133 - val_categorical_accuracy: 0.0900
# Epoch 5/10
# 1000/1000 [==============================] - 0s 59us/sample - loss: 110.3150 - categorical_accuracy: 0.1130 - val_loss: 109.8923 - val_categorical_accuracy: 0.0850
# Epoch 6/10
# 1000/1000 [==============================] - 0s 45us/sample - loss: 149.1865 - categorical_accuracy: 0.1030 - val_loss: 217.4751 - val_categorical_accuracy: 0.0750
# Epoch 7/10
# 1000/1000 [==============================] - 0s 53us/sample - loss: 197.7488 - categorical_accuracy: 0.1080 - val_loss: 123.0501 - val_categorical_accuracy: 0.0850
# Epoch 8/10
# 1000/1000 [==============================] - 0s 55us/sample - loss: 264.9575 - categorical_accuracy: 0.0980 - val_loss: 401.2721 - val_categorical_accuracy: 0.0750
# Epoch 9/10
# 1000/1000 [==============================] - 0s 51us/sample - loss: 502.0557 - categorical_accuracy: 0.1060 - val_loss: 622.3385 - val_categorical_accuracy: 0.0900
# Epoch 10/10
# 1000/1000 [==============================] - 0s 44us/sample - loss: 624.1157 - categorical_accuracy: 0.0770 - val_loss: 821.9027 - val_categorical_accuracy: 0.0750

# %% [markdown]
# ## 3.3 Input data from tf.data

# %%
dataset = tf.data.Dataset.from_tensor_slices((train_x,train_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()

val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.batch(32)
val_dataset = val_dataset.repeat()
model.fit(dataset, epochs=10, steps_per_epoch=30, validation_data=val_dataset, validation_steps=3)
# Out:
# Train for 30 steps, validate for 3 steps
# Epoch 1/10
# 30/30 [==============================] - 0s 15ms/step - loss: 1386.1909 - categorical_accuracy: 0.0917 - val_loss: 1909.7737 - val_categorical_accuracy: 0.0833
# Epoch 2/10
# 30/30 [==============================] - 0s 4ms/step - loss: 2187.8939 - categorical_accuracy: 0.0972 - val_loss: 2244.4266 - val_categorical_accuracy: 0.1250
# Epoch 3/10
# 30/30 [==============================] - 0s 5ms/step - loss: 3578.3886 - categorical_accuracy: 0.0908 - val_loss: 2288.1752 - val_categorical_accuracy: 0.1042
# Epoch 4/10
# 30/30 [==============================] - 0s 4ms/step - loss: 4596.5446 - categorical_accuracy: 0.0972 - val_loss: 4385.4404 - val_categorical_accuracy: 0.0833
# Epoch 5/10
# 30/30 [==============================] - 0s 5ms/step - loss: 6918.1601 - categorical_accuracy: 0.0769 - val_loss: 8482.1650 - val_categorical_accuracy: 0.0729
# Epoch 6/10
# 30/30 [==============================] - 0s 4ms/step - loss: 9434.8876 - categorical_accuracy: 0.0983 - val_loss: 17137.8626 - val_categorical_accuracy: 0.0833
# Epoch 7/10
# 30/30 [==============================] - 0s 4ms/step - loss: 10894.2148 - categorical_accuracy: 0.1004 - val_loss: 9102.1195 - val_categorical_accuracy: 0.1250
# Epoch 8/10
# 30/30 [==============================] - 0s 5ms/step - loss: 15690.9302 - categorical_accuracy: 0.0983 - val_loss: 16227.6452 - val_categorical_accuracy: 0.0833
# Epoch 9/10
# 30/30 [==============================] - 0s 4ms/step - loss: 13099.7688 - categorical_accuracy: 0.0876 - val_loss: 15528.2220 - val_categorical_accuracy: 0.1250
# Epoch 10/10
# 30/30 [==============================] - 0s 4ms/step - loss: 24924.8969 - categorical_accuracy: 0.0962 - val_loss: 17044.3691 - val_categorical_accuracy: 0.0833

# %% [markdown]
# 3.4 Evaluation and prediction

# %%
test_x = np.random.random((1000, 72))
test_y = np.random.random((1000, 10))
model.evaluate(test_x, test_y, batch_size=32)

test_data = tf.data.Dataset.from_tensor_slices((test_x, test_y))
test_data = test_data.batch(32).repeat()
model.evaluate(test_data, steps=30)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 30/30 [==============================] - 0s 3ms/step - loss: 16656.5504 - categorical_accuracy: 0.0990
# [16656.550390625, 0.098958336]

# %%
result = model.predict(test_x, batch_size=32)
print(result)
# Out:
# [[0.0000000e+00 0.0000000e+00 1.5832143e-23 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 1.3697486e-25 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 7.0954738e-23 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 0.0000000e+00 2.1426476e-24 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 4.0831635e-22 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 5.5259612e-23 ... 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]]

# %% [markdown]
# # Customize a high-level model
# ## 4.1 Function-like api
# Call tensors and return tensors.

# %%
input_x = keras.Input(shape=(72,))
hidden1 = keras.layers.Dense(32, activation='relu')(input_x)
hidden2  = keras.layers.Dense(16, activation='relu')(hidden1)
pred = keras.layers.Dense(10, activation='softmax')(hidden2)

model = tf.keras.Model(inputs=input_x, outputs=pred)
model.compile(optimizer=keras.optimizers.Adam(0.01), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 444us/sample - loss: 87.7781 - accuracy: 0.1150
# Epoch 2/5
# 1000/1000 [==============================] - 0s 142us/sample - loss: 386.5540 - accuracy: 0.1090
# Epoch 3/5
# 1000/1000 [==============================] - 0s 105us/sample - loss: 340.4630 - accuracy: 0.0900
# Epoch 4/5
# 1000/1000 [==============================] - 0s 96us/sample - loss: 703.8081 - accuracy: 0.1010
# Epoch 5/5
# 1000/1000 [==============================] - 0s 158us/sample - loss: 1164.3914 - accuracy: 0.1040

# %% [markdown]
# ## 4.2 Define a subclass model

# %%
class MyModel(tf.keras.Model):
    def __init__(self, num_class=10):
        super(MyModel, self).__init__(name='my_model')
        self.num_classes = num_class
        self.layer1 = keras.layers.Dense(32, activation='relu')
        self.layer2 = keras.layers.Dense(num_class, activation='softmax')
        
    def call(self, inputs, training=None, mask=None):
        h1 = self.layer1(inputs)
        out = self.layer2(h1)
        return out
    
    def compute_output_shape(self, input_shape):
        shape = tf.TensorShape(input_shape).as_list()
        shape[-1] = self.num_classes
        return tf.TensorShape(shape)

# %%
model = MyModel(num_class=10)
model.compile(optimizer=keras.optimizers.RMSprop(0.001), 
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=10, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 926us/sample - loss: 17.5623 - accuracy: 0.1170
# Epoch 2/5
# 1000/1000 [==============================] - 0s 253us/sample - loss: 28.3798 - accuracy: 0.1130
# Epoch 3/5
# 1000/1000 [==============================] - 0s 300us/sample - loss: 34.9736 - accuracy: 0.1020
# Epoch 4/5
# 1000/1000 [==============================] - 0s 261us/sample - loss: 39.5450 - accuracy: 0.1120
# Epoch 5/5
# 1000/1000 [==============================] - 0s 277us/sample - loss: 44.8806 - accuracy: 0.0960

# %% [markdown]
# ## 4.3 Customize layers
# Create a subclass of a layer, including following functions:
#
# 1.1  `build` : initialize weights.
#
# 1.2  `call` : propagation.
#
# 1.3  etc. :`compute_output_shape`, `get_config`, `from_config`

# %%
class MyLayers(tf.keras.layers.Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(MyLayers, self).__init__(**kwargs)
    
    def build(self, input_shape):
        weight_shape = tf.TensorShape((input_shape[1], self.output_dim))
        self.kernel = self.add_weight(name='kernel1', shape=weight_shape, initializer='uniform', trainable=True)
        super(MyLayers, self).build(input_shape)
        
    def call(self, inputs):
        return tf.matmul(inputs, self.kernel)
    
    def compute_output_shape(self, input_shape):
        shape = tf.TensorShape(input_shape).as_list()
        shape[-1] = self.output_dim
        return tf.TensorShape(shape)
    
    def get_config(self):
        base_config = super(MyLayers, self).get_config()
        base_config['output_dim'] = self.output_dim
        return base_config
    
    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
model = keras.Sequential([
    MyLayers(10),
    keras.layers.Activation('softmax')
])
model.compile(optimizer=keras.optimizers.RMSprop(0.01),
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.fit(train_x, train_y, batch_size=10, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 504us/sample - loss: 11.5055 - accuracy: 0.0900
# Epoch 2/5
# 1000/1000 [==============================] - 0s 281us/sample - loss: 11.4759 - accuracy: 0.1090
# Epoch 3/5
# 1000/1000 [==============================] - 0s 223us/sample - loss: 11.4915 - accuracy: 0.0890
# Epoch 4/5
# 1000/1000 [==============================] - 0s 234us/sample - loss: 11.4943 - accuracy: 0.1020
# Epoch 5/5
# 1000/1000 [==============================] - 0s 230us/sample - loss: 11.4958 - accuracy: 0.1060

# %% [markdown]
# ## 4.3 Callback

# %%
callbacks = [
    keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
    keras.callbacks.TensorBoard(log_dir=r'.\logs')
]
model.fit(train_x, train_y, batch_size=10, epochs=5, callbacks=callbacks, validation_data=(val_x, val_y))
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 389us/sample - loss: 11.4900 - accuracy: 0.1120 - val_loss: 11.9521 - val_accuracy: 0.1100
# Epoch 2/5
# 1000/1000 [==============================] - 0s 308us/sample - loss: 11.4942 - accuracy: 0.0950 - val_loss: 11.9087 - val_accuracy: 0.1050
# Epoch 3/5
# 1000/1000 [==============================] - 0s 289us/sample - loss: 11.4857 - accuracy: 0.0940 - val_loss: 11.9267 - val_accuracy: 0.1250
# Epoch 4/5
# 1000/1000 [==============================] - 0s 288us/sample - loss: 11.4928 - accuracy: 0.0860 - val_loss: 11.8816 - val_accuracy: 0.1100
# Epoch 5/5
# 1000/1000 [==============================] - 0s 365us/sample - loss: 11.4933 - accuracy: 0.0990 - val_loss: 11.8909 - val_accuracy: 0.1550

# %% [markdown]
# # 5 Save and Recover
# ## 5.1 Save weights

# %%
model = tf.keras.Sequential([
keras.layers.Dense(64, activation='relu'),
keras.layers.Dense(10, activation='softmax')])
model.build(input_shape=([None, 72]))
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.save_weights(r'.\weights\model')
model.load_weights(r'.\weights\model')
model.save_weights(r'\model.h5')
model.load_weights(r'\model.h5')

# %% [markdown]
# ## 5.2 Save network
# 5.2.1 By json file

# %%
import json
import pprint
json_str = model.to_json()
pprint.pprint(json.loads(json_str))
fresh_model = keras.models.model_from_json(json_str)
# Out:
# {'backend': 'tensorflow',
#  'class_name': 'Sequential',
#  'config': {'build_input_shape': [None, 72],
#             'layers': [{'class_name': 'Dense',
#                         'config': {'activation': 'relu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_28',
#                                    'trainable': True,
#                                    'units': 64,
#                                    'use_bias': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'softmax',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_29',
#                                    'trainable': True,
#                                    'units': 10,
#                                    'use_bias': True}}],
#             'name': 'sequential_6'},
#  'keras_version': '2.2.4-tf'}

# %% [markdown]
# 5.2.2 By yaml file

# %%
yaml_str = model.to_yaml()
print(yaml_str)
fresh_model = keras.models.model_from_yaml(yaml_str)
# Out:
# backend: tensorflow
# class_name: Sequential
# config:
#   build_input_shape: !!python/tuple
#   - null
#   - 72
#   layers:
#   - class_name: Dense
#     config:
#       activation: relu
#       activity_regularizer: null
#       bias_constraint: null
#       bias_initializer:
#         class_name: Zeros
#         config: {}
#       bias_regularizer: null
#       dtype: float32
#       kernel_constraint: null
#       kernel_initializer:
#         class_name: GlorotUniform
#         config:
#           seed: null
#       kernel_regularizer: null
#       name: dense_28
#       trainable: true
#       units: 64
#       use_bias: true
#   - class_name: Dense
#     config:
#       activation: softmax
#       activity_regularizer: null
#       bias_constraint: null
#       bias_initializer:
#         class_name: Zeros
#         config: {}
#       bias_regularizer: null
#       dtype: float32
#       kernel_constraint: null
#       kernel_initializer:
#         class_name: GlorotUniform
#         config:
#           seed: null
#       kernel_regularizer: null
#       name: dense_29
#       trainable: true
#       units: 10
#       use_bias: true
#   name: sequential_6
# keras_version: 2.2.4-tf
# D:\Users\shelb\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\model_config.py:76: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(yaml_string)

# %% [markdown]
# ## 5.3 Save model

# %%
model.save('all_model.h5')
model = tf.keras.models.load_model('all_model.h5')

# %% [markdown]
# # Keras to Estimator API

# %%
estimator = keras.estimator.model_to_estimator(model)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\shelb\AppData\Local\Temp\tmpxtqyz563
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:You are creating an Estimator from a Keras model manually subclassed from `Model`, that was already called on some inputs (and thus already had weights). We are currently unable to preserve the model's state (its weights) as part of the estimator in this case. Be warned that the estimator has been created using a freshly initialized version of your model.
# Note that this doesn't affect the state of the model instance you passed as `keras_model` argument.
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\shelb\\AppData\\Local\\Temp\\tmpxtqyz563', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000261FF963D30>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
